# %% [markdown]
# ## Heart Disease Predictor
# * load The data
# * Basic Check
# * eda

# %% [markdown]
# # Import Libraries

# %%
#import libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# #### Load The Data

# %%
heart_df=pd.read_csv("../data/raw/heart_disease.csv")
heart_df.head()
# Out:
#   HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 0           No  16.60     Yes              No     No               3
# 1           No  20.34      No              No    Yes               0
# 2           No  26.58     Yes              No     No              20
# 3           No  24.21      No              No     No               0
# 4           No  23.71      No              No     No              28
#
#    MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 0            30          No  Female        55-59  White      Yes
# 1             0          No  Female  80 or older  White       No
# 2            30          No    Male        65-69  White      Yes
# 3             0          No  Female        75-79  White       No
# 4             0         Yes  Female        40-44  White       No
#
#   PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# 0              Yes  Very good          5    Yes            No        Yes
# ...

# %%
heart_df.columns
# Out:
# Index(['HeartDisease', 'BMI', 'Smoking', 'AlcoholDrinking', 'Stroke',
#        'PhysicalHealth', 'MentalHealth', 'DiffWalking', 'Sex', 'AgeCategory',
#        'Race', 'Diabetic', 'PhysicalActivity', 'GenHealth', 'SleepTime',
#        'Asthma', 'KidneyDisease', 'SkinCancer'],
#       dtype='object')

# %% [markdown]
# # Conduct BasicCheck

# %%
heart_df.isnull().sum() # check missing values
# Out:
# HeartDisease        0
# BMI                 0
# Smoking             0
# AlcoholDrinking     0
# Stroke              0
# PhysicalHealth      0
# MentalHealth        0
# DiffWalking         0
# Sex                 0
# AgeCategory         0
# Race                0
# Diabetic            0
# PhysicalActivity    0
# GenHealth           0
# SleepTime           0
# Asthma              0
# KidneyDisease       0
# SkinCancer          0
# dtype: int64

# %%
# check duplicates
heart_df.duplicated().sum()
# Out:
# np.int64(18078)

# %%
heart_df[heart_df.duplicated(keep=False)].head()
# Out:
#     HeartDisease    BMI Smoking AlcoholDrinking Stroke  PhysicalHealth  \
# 24            No  25.75      No              No     No               0
# 41            No  28.13      No              No     No               0
# 46            No  33.23      No              No     No               0
# 102           No  23.49      No              No     No               0
# 104           No  25.09     Yes              No     No               0
#
#      MentalHealth DiffWalking     Sex  AgeCategory   Race Diabetic  \
# 24              0          No  Female  80 or older  White       No
# 41              0          No    Male        60-64  White       No
# 46              0          No    Male        65-69  White      Yes
# 102             0          No  Female        70-74  White       No
# 104             0          No    Male        65-69  White       No
#
#     PhysicalActivity  GenHealth  SleepTime Asthma KidneyDisease SkinCancer
# ...

# %%
# remove duplicates to keep our data clean
heart_df=heart_df.drop_duplicates().reset_index()

# %%
heart_df.duplicated().sum()
# Out:
# np.int64(0)

# %%
# re-check the data integrity whether it balanced or not 
heart_df.HeartDisease.value_counts(normalize=True)
# Out:
# HeartDisease
# No     0.909647
# Yes    0.090353
# Name: proportion, dtype: float64

# %%
heart_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 301717 entries, 0 to 301716
# Data columns (total 19 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   index             301717 non-null  int64
#  1   HeartDisease      301717 non-null  object
#  2   BMI               301717 non-null  float64
#  3   Smoking           301717 non-null  object
#  4   AlcoholDrinking   301717 non-null  object
#  5   Stroke            301717 non-null  object
#  6   PhysicalHealth    301717 non-null  int64
#  7   MentalHealth      301717 non-null  int64
#  8   DiffWalking       301717 non-null  object
#  9   Sex               301717 non-null  object
#  10  AgeCategory       301717 non-null  object
#  11  Race              301717 non-null  object
#  12  Diabetic          301717 non-null  object
#  13  PhysicalActivity  301717 non-null  object
#  14  GenHealth         301717 non-null  object
#  15  SleepTime         301717 non-null  int64
# ...
